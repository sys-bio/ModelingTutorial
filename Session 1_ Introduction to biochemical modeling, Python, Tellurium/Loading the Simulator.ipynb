# %%
# !apt-get install libncurses5
# !pip install -q tellurium==2.2.8
# !pip install -q teUtils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libncurses5 is already the newest version (6.2-0ubuntu2.1).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.

# %%
import matplotlib.pyplot as plt
import numpy as np
import teUtils as tu
import tellurium as te

# %%
p1 = tu.buildNetworks.getLinearChain(20, "Michaelis")

# %%
print (p1)
# Out:
# J1: $Xo -> S1; Vm1/Km10*(Xo-S1/Keq1)/(1 + Xo/Km10 + S1/Km11);
# J2: S1 -> S2; Vm2/Km20*(S1-S2/Keq2)/(1 + S1/Km20 + S2/Km21);
# J3: S2 -> S3; Vm3/Km30*(S2-S3/Keq3)/(1 + S2/Km30 + S3/Km31);
# J4: S3 -> S4; Vm4/Km40*(S3-S4/Keq4)/(1 + S3/Km40 + S4/Km41);
# J5: S4 -> S5; Vm5/Km50*(S4-S5/Keq5)/(1 + S4/Km50 + S5/Km51);
# J6: S5 -> S6; Vm6/Km60*(S5-S6/Keq6)/(1 + S5/Km60 + S6/Km61);
# J7: S6 -> S7; Vm7/Km70*(S6-S7/Keq7)/(1 + S6/Km70 + S7/Km71);
# J8: S7 -> S8; Vm8/Km80*(S7-S8/Keq8)/(1 + S7/Km80 + S8/Km81);
# J9: S8 -> S9; Vm9/Km90*(S8-S9/Keq9)/(1 + S8/Km90 + S9/Km91);
# J10: S9 -> S10; Vm10/Km100*(S9-S10/Keq10)/(1 + S9/Km100 + S10/Km101);
# J11: S10 -> S11; Vm11/Km110*(S10-S11/Keq11)/(1 + S10/Km110 + S11/Km111);
# J12: S11 -> S12; Vm12/Km120*(S11-S12/Keq12)/(1 + S11/Km120 + S12/Km121);
# J13: S12 -> S13; Vm13/Km130*(S12-S13/Keq13)/(1 + S12/Km130 + S13/Km131);
# J14: S13 -> S14; Vm14/Km140*(S13-S14/Keq14)/(1 + S13/Km140 + S14/Km141);
# J15: S14 -> S15; Vm15/Km150*(S14-S15/Keq15)/(1 + S14/Km150 + S15/Km151);
# J16: S15 -> S16; Vm16/Km160*(S15-S16/Keq16)/(1 + S15/Km160 + S16/Km161);
# J17: S16 -> S17; Vm17/Km170*(S16-S17/Keq17)/(1 + S16/Km170 + S17/Km171);
# J18: S17 -> S18; Vm18/Km180*(S17-S18/Keq18)/(1 + S17/Km180 + S18/Km181);
# J19: S18 -> S19; Vm19/Km190*(S18-S19/Keq19)/(1 + S18/Km190 + S19/Km191);
# J20: S19 -> $X1; Vm20/Km200*(S19-X1/Keq20)/(1 + S19/Km200 + X1/Km201);
#
# Vm1 = 5.88
# Vm2 = 0.29
# Vm3 = 1.69
# Vm4 = 0.91
# Vm5 = 3.19
# Vm6 = 8.23
# Vm7 = 4.11
# Vm8 = 5.67
# Vm9 = 9.29
# Vm10 = 3.79
# Vm11 = 1.00
# Vm12 = 2.18
# Vm13 = 8.23
# Vm14 = 3.60
# Vm15 = 4.79
# Vm16 = 4.99
# Vm17 = 2.36
# Vm18 = 3.12
# Vm19 = 3.80
# Vm20 = 2.79
# Km10 = 1.07
# Km11 = 2.32
# Km20 = 0.43
# Km21 = 4.64
# Km30 = 4.94
# Km31 = 0.50
# Km40 = 8.04
# Km41 = 5.93
# Km50 = 4.49
# Km51 = 6.71
# Km60 = 0.91
# Km61 = 7.01
# Km70 = 9.84
# Km71 = 7.24
# Km80 = 7.35
# Km81 = 0.64
# Km90 = 5.92
# Km91 = 7.54
# Km100 = 1.52
# Km101 = 3.46
# Km110 = 6.25
# Km111 = 2.75
# Km120 = 6.33
# Km121 = 2.93
# Km130 = 7.88
# Km131 = 0.31
# Km140 = 4.95
# Km141 = 7.34
# Km150 = 6.53
# Km151 = 0.50
# Km160 = 3.39
# Km161 = 8.87
# Km170 = 2.84
# Km171 = 7.07
# Km180 = 3.09
# Km181 = 7.44
# Km190 = 3.15
# Km191 = 7.12
# Km200 = 6.85
# Km201 = 9.19
# Keq1 = 1.26
# Keq2 = 8.30
# Keq3 = 0.83
# Keq4 = 6.25
# Keq5 = 8.50
# Keq6 = 8.01
# Keq7 = 4.45
# Keq8 = 8.68
# Keq9 = 0.08
# Keq10 = 7.17
# Keq11 = 1.59
# Keq12 = 8.19
# Keq13 = 5.60
# Keq14 = 2.66
# Keq15 = 5.24
# Keq16 = 3.64
# Keq17 = 7.49
# Keq18 = 3.56
# Keq19 = 1.67
# Keq20 = 8.83
# Xo = 4.00
# X1 = 0
# S1 = 0; S2 = 0; S3 = 0; S4 = 0;
# S5 = 0; S6 = 0; S7 = 0; S8 = 0;
# S9 = 0; S10 = 0; S11 = 0; S12 = 0;
# S13 = 0; S14 = 0; S15 = 0; S16 = 0;
# S17 = 0; S18 = 0; S19 = 0;

# %%
r =  te.loada (p1)

# %%
r.steadyState()
# Out:
# 1.369933000334949e-13

# %%
tu.plotting.plotFloatingSpecies(r)

# %%
tu.plotting.plotFluxControlHeatMap(r)
